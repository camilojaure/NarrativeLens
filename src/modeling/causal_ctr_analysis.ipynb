# %% [markdown]
# # Causal Inference: Do Creative Features Affect CTR?

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from econml.dml import LinearDML

# %%
# Load dataset
df = pd.read_csv('../../data/datasets/tiktok_ads_us_toplikes.csv')

# %%
df.head()
# Out:
#                                      ad_title                    brand_name  \
# 0                          Great time killer!          Survival Game Master
# 1                       Oddly satisfying game              Gameworld Master
# 2  My friend recommended me to play this game  Sugarcane Inc. Empire Tycoon
# 3                                download now      Smart VPN - Fast, Stable
# 4   Play ten minutes a day to relieve stress!          Sugarcane Factory 3D
#
#    cost   ctr  favorite                   id  is_search    like      tag  \
# 0     2  0.01     False  7132878852058906625       True   38213      3.0
# 1     2  0.01     False  7109275920046178305       True   14299      3.0
# 2     0  0.02     False  7077499601561305089       True    2427  unknown
# 3     2  0.02     False  7176836203668783106       True  124771      3.0
# 4     0  0.02     False  7077499507373899777       True    2739  unknown
#
#                                      detail_analysis  ...  \
# 0  This ad is using Product Review to catch audie...  ...
# 1  This ad is using Strategy Focused to catch aud...  ...
# 2                                                NaN  ...
# 3  This ad is using Oddly Satisfying to catch aud...  ...
# 4                                                NaN  ...
#
#   industry_parent.value objective_id objective_value  \
# 0  News & Entertainment            2    App Installs
# 1  News & Entertainment            2    App Installs
# 2  News & Entertainment            2    App Installs
# 3  News & Entertainment            2    App Installs
# 4  News & Entertainment            2    App Installs
#
#    creative_features_creative_theme creative_features_creative_concept  \
# 0         Promotional & Offer-Based                       Product demo
# 1                   Product-Centric                       Product demo
# 2           Educational & Explainer                       Product demo
# 3          Lifestyle & Aspirational             Before-and-after story
# 4                   Product-Centric                       Product demo
#
#    creative_features_format_production_style  creative_features_talent_type  \
# 0                               Native Video                    Influencers
# 1                               Native Video                            NaN
# 2                Animation & Motion Graphics                            NaN
# 3                Animation & Motion Graphics                            NaN
# 4                Animation & Motion Graphics                            NaN
#
#   creative_features_demographic_representation  \
# 0                               Primarily Male
# 1                           No People Featured
# 2                           No People Featured
# 3                             Primarily Female
# 4                           No People Featured
#
#   creative_features_audience_focus  creative_features_campaign_objective
# 0                 Unaware Audience                         App Promotion
# 1                 Unaware Audience                             Awareness
# 2                 Unaware Audience                             Awareness
# 3                          Unclear                            Engagement
# 4                 Unaware Audience                         App Promotion
#
# [5 rows x 28 columns]

# %%
# Define outcome, treatment, and control features
outcome = 'ctr'
creative_features = [
    'creative_features_creative_theme',
    'creative_features_creative_concept',
    'creative_features_format_production_style',
    'creative_features_talent_type',
    'creative_features_demographic_representation',
    'creative_features_audience_focus',
    'creative_features_campaign_objective'
]
control_features = ['cost', 'industry_parent.value', 'objective_value']
df_model = df[[outcome] + creative_features + control_features].copy()
df_model = df_model[df_model[outcome].notna()]

# %%
df_model.head()
# Out:
#     ctr creative_features_creative_theme creative_features_creative_concept  \
# 0  0.01        Promotional & Offer-Based                       Product demo
# 1  0.01                  Product-Centric                       Product demo
# 2  0.02          Educational & Explainer                       Product demo
# 3  0.02         Lifestyle & Aspirational             Before-and-after story
# 4  0.02                  Product-Centric                       Product demo
#
#   creative_features_format_production_style creative_features_talent_type  \
# 0                              Native Video                   Influencers
# 1                              Native Video                           NaN
# 2               Animation & Motion Graphics                           NaN
# 3               Animation & Motion Graphics                           NaN
# 4               Animation & Motion Graphics                           NaN
#
#   creative_features_demographic_representation  \
# 0                               Primarily Male
# 1                           No People Featured
# 2                           No People Featured
# 3                             Primarily Female
# 4                           No People Featured
#
#   creative_features_audience_focus creative_features_campaign_objective  cost  \
# 0                 Unaware Audience                        App Promotion     2
# 1                 Unaware Audience                            Awareness     2
# 2                 Unaware Audience                            Awareness     0
# 3                          Unclear                           Engagement     2
# 4                 Unaware Audience                        App Promotion     0
#
#   industry_parent.value objective_value
# 0  News & Entertainment    App Installs
# 1  News & Entertainment    App Installs
# 2  News & Entertainment    App Installs
# 3  News & Entertainment    App Installs
# 4  News & Entertainment    App Installs

# %%
# Preprocessing
categorical_features = creative_features + ['industry_parent.value', 'objective_value']
numerical_features = ['cost']

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # mode for categorical
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))  # median for numeric
])

preprocessor = ColumnTransformer(transformers=[
    ('cat', categorical_transformer, categorical_features),
    ('num', numerical_transformer, numerical_features)
])

# %%
# Transform data
X = preprocessor.fit_transform(df_model.drop(columns=[outcome]))
y = df_model[outcome].values

# %%
X.shape, y.shape
# Out:
# ((582, 91), (582,))

# %%
# Extract treatment and control matrices robustly
onehot = preprocessor.named_transformers_['cat'].named_steps['onehot']
encoded_feature_names = onehot.get_feature_names_out(categorical_features)

# Find indices of creative_features in categorical_features
creative_indices = [categorical_features.index(f) for f in creative_features]

# Calculate number of one-hot columns for treatments
num_treatments = sum([len(onehot.categories_[i]) for i in creative_indices])

T = X[:, :num_treatments]
W = X[:, num_treatments:]

# %%
T.shape, W.shape
# Out:
# ((582, 66), (582, 25))

# %%
missing = [col for col in creative_features if col not in df_model.columns]
print("Missing creative_features columns:", missing)
# Out:
# Missing creative_features columns: []

# %%
# Remove rows with missing values in outcome, treatment, or controls
required_cols = [outcome, treatment_col] + [col for col in df_model.columns if col not in [outcome, treatment_col]]
df_model_clean = df_model.dropna(subset=required_cols)

y = df_model_clean[outcome].values
T = df_model_clean[[treatment_col]].values
W = df_model_clean[[col for col in df_model_clean.columns if col not in [outcome, treatment_col]]].values

# Fit Linear DML
model_y = RandomForestRegressor(n_estimators=100, min_samples_leaf=10)
model_t = RandomForestClassifier(n_estimators=100, min_samples_leaf=10)
dml = LinearDML(model_y=model_y, model_t=model_t, discrete_treatment=True, cv=3, random_state=0)

dml.fit(Y=y, T=T, X=W)
# Out:
# The least populated class in y has only 2 members, which is less than n_splits=3.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 14
#      11 model_t = RandomForestClassifier(n_estimators=100, min_samples_leaf=10)
#      12 dml = LinearDML(model_y=model_y, model_t=model_t, discrete_treatment=True, cv=3, random_state=0)
# ---> 14 dml.fit(Y=y, T=T, X=W)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/dml/dml.py:821, in LinearDML.fit(self, Y, T, X, W, sample_weight, freq_weight, sample_var, groups, cache_values, inference)
#     782 def fit(self, Y, T, *, X=None, W=None, sample_weight=None, freq_weight=None, sample_var=None, groups=None,
#     783         cache_values=False, inference='auto'):
#     784     """
#     785     Estimate the counterfactual model from data, i.e. estimates functions τ(·,·,·), ∂τ(·,·).
#     786
#    (...)
#     819     self
#     820     """
# --> 821     return super().fit(Y, T, X=X, W=W,
#     822                        sample_weight=sample_weight, freq_weight=freq_weight, sample_var=sample_var, groups=groups,
#     823                        cache_values=cache_values,
#     824                        inference=inference)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/dml/dml.py:589, in DML.fit(self, Y, T, X, W, sample_weight, freq_weight, sample_var, groups, cache_values, inference)
#     550 def fit(self, Y, T, *, X=None, W=None, sample_weight=None, freq_weight=None, sample_var=None, groups=None,
#     551         cache_values=False, inference='auto'):
#     552     """
#     553     Estimate the counterfactual model from data, i.e. estimates functions τ(·,·,·), ∂τ(·,·).
#     554
#    (...)
#     587     self
#     588     """
# --> 589     return super().fit(Y, T, X=X, W=W, sample_weight=sample_weight, freq_weight=freq_weight,
#     590                        sample_var=sample_var, groups=groups,
#     591                        cache_values=cache_values,
#     592                        inference=inference)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/dml/_rlearner.py:415, in _RLearner.fit(self, Y, T, X, W, sample_weight, freq_weight, sample_var, groups, cache_values, inference)
#     378 """
#     379 Estimate the counterfactual model from data, i.e. estimates function :math:`\\theta(\\cdot)`.
#     380
#    (...)
#     412 self: _RLearner instance
#     413 """
#     414 # Replacing fit from _OrthoLearner, to enforce Z=None and improve the docstring
# --> 415 return super().fit(Y, T, X=X, W=W,
#     416                    sample_weight=sample_weight, freq_weight=freq_weight, sample_var=sample_var, groups=groups,
#     417                    cache_values=cache_values,
#     418                    inference=inference)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/_cate_estimator.py:131, in BaseCateEstimator._wrap_fit.<locals>.call(self, Y, T, inference, *args, **kwargs)
#     129     inference.prefit(self, Y, T, *args, **kwargs)
#     130 # call the wrapped fit method
# --> 131 m(self, Y, T, *args, **kwargs)
#     132 self._postfit(Y, T, *args, **kwargs)
#     133 if inference is not None:
#     134     # NOTE: we call inference fit *after* calling the main fit method
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/_ortho_learner.py:822, in _OrthoLearner.fit(self, Y, T, X, W, Z, sample_weight, freq_weight, sample_var, groups, cache_values, inference, only_final, check_input)
#     820     nuisances, fitted_models, new_inds, scores = ray.get(self.nuisances_ref[idx])
#     821 else:
# --> 822     nuisances, fitted_models, new_inds, scores = self._fit_nuisances(
#     823         Y, T, X, W, Z, sample_weight=sample_weight_nuisances, groups=groups)
#     824 all_nuisances.append(nuisances)
#     825 self._models_nuisance.append(fitted_models)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/_ortho_learner.py:972, in _OrthoLearner._fit_nuisances(self, Y, T, X, W, Z, sample_weight, groups)
#     969     else:
#     970         folds = splitter.split(to_split, strata)
# --> 972 nuisances, fitted_models, fitted_inds, scores = _crossfit(self._ortho_learner_model_nuisance, folds,
#     973                                                           self.use_ray, self.ray_remote_func_options, Y, T,
#     974                                                           X=X, W=W, Z=Z, sample_weight=sample_weight,
#     975                                                           groups=groups)
#     976 return nuisances, fitted_models, fitted_inds, scores
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/_ortho_learner.py:280, in _crossfit(models, folds, use_ray, ray_remote_fun_option, *args, **kwargs)
#     278     nuisance_temp, model_out, score_temp = ray.get(fold_refs[idx])
#     279 else:
# --> 280     nuisance_temp, model_out, score_temp = _fit_fold(model, train_idxs, test_idxs,
#     281                                                      calculate_scores, accumulated_args, kwargs)
#     283 if idx == 0:
#     284     nuisances = tuple([np.full((n,) + nuis.shape[1:], np.nan)
#     285                       for nuis in nuisance_temp])
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/_ortho_learner.py:99, in _fit_fold(model, train_idxs, test_idxs, calculate_scores, args, kwargs)
#      96 kwargs_train = {key: var[train_idxs] for key, var in kwargs.items()}
#      97 kwargs_test = {key: var[test_idxs] for key, var in kwargs.items()}
# ---> 99 model.train(False, None, *args_train, **kwargs_train)
#     100 nuisance_temp = model.predict(*args_test, **kwargs_test)
#     102 if not isinstance(nuisance_temp, tuple):
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/dml/_rlearner.py:53, in _ModelNuisance.train(self, is_selecting, folds, Y, T, X, W, Z, sample_weight, groups)
#      51 def train(self, is_selecting, folds, Y, T, X=None, W=None, Z=None, sample_weight=None, groups=None):
#      52     assert Z is None, "Cannot accept instrument!"
# ---> 53     self._model_t.train(is_selecting, folds, X, W, T, **
#      54                         filter_none_kwargs(sample_weight=sample_weight, groups=groups))
#      55     self._model_y.train(is_selecting, folds, X, W, Y, **
#      56                         filter_none_kwargs(sample_weight=sample_weight, groups=groups))
#      57     return self
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/dml/dml.py:95, in _FirstStageSelector.train(self, is_selecting, folds, X, W, Target, sample_weight, groups)
#      91         raise AttributeError("Provided crossfit folds contain training splits that " +
#      92                              "don't contain all treatments")
#      93     Target = inverse_onehot(Target)
# ---> 95 self._model.train(is_selecting, folds, _combine(X, W, Target.shape[0]), Target,
#      96                   **filter_none_kwargs(groups=groups, sample_weight=sample_weight))
#      97 return self
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/sklearn_extensions/model_selection.py:407, in FixedModelSelector.train(self, is_selecting, folds, X, y, groups, **kwargs)
#     404         self._score = np.mean(scores)
#     405 else:
#     406     # we need to train the model on the data
# --> 407     _fit_with_groups(self.model, X, y, groups=groups, **kwargs)
#     409 return self
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/econml/sklearn_extensions/model_selection.py:378, in _fit_with_groups(model, X, y, sub_model, groups, **kwargs)
#     375             sub_model.cv = old_cv
#     377 # drop groups from arg list, which were already used at the outer level and may not be supported by the model
# --> 378 return model.fit(X, y, **kwargs)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/sklearn/utils/validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/sklearn/utils/validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File ~/Documents/Projects/Developments/NarrativeLens/NarrativeLens/lib/python3.10/site-packages/sklearn/utils/_array_api.py:745, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     743     array = numpy.array(array, order=order, dtype=dtype)
#     744 else:
# --> 745     array = numpy.asarray(array, order=order, dtype=dtype)
#     747 # At this point array is a NumPy ndarray. We convert it to an array
#     748 # container that is consistent with the input's namespace.
#     749 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'Product demo'

# %%
# Summarize effects
import matplotlib.pyplot as plt
effects = pd.DataFrame({
    'treatment': encoded_feature_names[:num_treatments],
    'coef': dml.coef_,
    'stderr': dml.stderr_,
    'ci_lower': dml.coef_ - 1.96 * dml.stderr_,
    'ci_upper': dml.coef_ + 1.96 * dml.stderr_
})
effects.sort_values(by='coef', ascending=False).head(10)
